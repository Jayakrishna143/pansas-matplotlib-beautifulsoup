# %% [markdown]
# <a href="https://colab.research.google.com/github/Jayakrishna143/pansas-matplotlib-beautifulsoup/blob/main/pjayakrishna355_irisdata_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gdown,pandas as pd,numpy as np
gdown.download(url='https://drive.google.com/file/d/1fxMYwtD4O6ReF960ozU5AufPFh4KO0vt/view',output='iris_data.csv',quiet=True,fuzzy=True)
# Out:
# 'iris_data.csv'

# %%
df = pd.read_csv('/content/iris_data.csv')
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#              target
# ...

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %% [markdown]
# ####Q1
# - Rename the columns of the dataset to 'SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Species'

# %%
df.columns = ["SepalLength",'SepalWidth','PetalLength','PetalWidth','Species']

# %% [markdown]
# ####Q2
# - a: Set the index of the DataFrame to the 'species' column

# %%
df.set_index('Species')
# Out:
#                 SepalLength  SepalWidth  PetalLength  PetalWidth
# Species
# Iris-setosa             5.1         3.5          1.4         0.2
# Iris-setosa             4.9         3.0          1.4         0.2
# Iris-setosa             4.7         3.2          1.3         0.2
# Iris-setosa             4.6         3.1          1.5         0.2
# Iris-setosa             5.0         3.6          1.4         0.2
# ...                     ...         ...          ...         ...
# Iris-virginica          6.7         3.0          5.2         2.3
# Iris-virginica          6.3         2.5          5.0         1.9
# Iris-virginica          6.5         3.0          5.2         2.0
# Iris-virginica          6.2         3.4          5.4         2.3
# Iris-virginica          5.9         3.0          5.1         1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# - b: Retrieve the first 10 rows of the DataFrame using integer_based indexing

# %%
df.iloc[1:11]
# Out:
#     SepalLength  SepalWidth  PetalLength  PetalWidth      Species
# 1           4.9         3.0          1.4         0.2  Iris-setosa
# 2           4.7         3.2          1.3         0.2  Iris-setosa
# 3           4.6         3.1          1.5         0.2  Iris-setosa
# 4           5.0         3.6          1.4         0.2  Iris-setosa
# 5           5.4         3.9          1.7         0.4  Iris-setosa
# 6           4.6         3.4          1.4         0.3  Iris-setosa
# 7           5.0         3.4          1.5         0.2  Iris-setosa
# 8           4.4         2.9          1.4         0.2  Iris-setosa
# 9           4.9         3.1          1.5         0.1  Iris-setosa
# 10          5.4         3.7          1.5         0.2  Iris-setosa

# %% [markdown]
# ###Q3
# - a. Slice the DataFrame to display rows with "petalWidth" with grater than 2.5

# %%
df[df["PetalWidth"]>2.5]
# Out:
# Empty DataFrame
# Columns: [SepalLength, SepalWidth, PetalLength, PetalWidth, Species]
# Index: []

# %% [markdown]
# - b. slice the datafreame to display columns"speallength"  and "spealwidth" for the first 5 rows

# %%
df[['SepalLength','SepalWidth']].head()
# Out:
#    SepalLength  SepalWidth
# 0          5.1         3.5
# 1          4.9         3.0
# 2          4.7         3.2
# 3          4.6         3.1
# 4          5.0         3.6

# %% [markdown]
# ### Q4
# #### a. Filter the DataFrame to show only rows where Species is Versicolor

# %%
df[df["Species"] == 'Iris-versicolor']
# Out:
#     SepalLength  SepalWidth  PetalLength  PetalWidth          Species
# 50          7.0         3.2          4.7         1.4  Iris-versicolor
# 51          6.4         3.2          4.5         1.5  Iris-versicolor
# 52          6.9         3.1          4.9         1.5  Iris-versicolor
# 53          5.5         2.3          4.0         1.3  Iris-versicolor
# 54          6.5         2.8          4.6         1.5  Iris-versicolor
# 55          5.7         2.8          4.5         1.3  Iris-versicolor
# 56          6.3         3.3          4.7         1.6  Iris-versicolor
# 57          4.9         2.4          3.3         1.0  Iris-versicolor
# 58          6.6         2.9          4.6         1.3  Iris-versicolor
# 59          5.2         2.7          3.9         1.4  Iris-versicolor
# 60          5.0         2.0          3.5         1.0  Iris-versicolor
# 61          5.9         3.0          4.2         1.5  Iris-versicolor
# ...

# %% [markdown]
# #### b. Filter the dataframe tho show rows where PetalLength is Grater than $ and SepalWidth is less than 3

# %%
#method 1 easy
df.query('PetalLength > 4 and SepalWidth <3')
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth          Species
# 54           6.5         2.8          4.6         1.5  Iris-versicolor
# 55           5.7         2.8          4.5         1.3  Iris-versicolor
# 58           6.6         2.9          4.6         1.3  Iris-versicolor
# 63           6.1         2.9          4.7         1.4  Iris-versicolor
# 67           5.8         2.7          4.1         1.0  Iris-versicolor
# 68           6.2         2.2          4.5         1.5  Iris-versicolor
# 72           6.3         2.5          4.9         1.5  Iris-versicolor
# 73           6.1         2.8          4.7         1.2  Iris-versicolor
# 74           6.4         2.9          4.3         1.3  Iris-versicolor
# 76           6.8         2.8          4.8         1.4  Iris-versicolor
# 78           6.0         2.9          4.5         1.5  Iris-versicolor
# 83           6.0         2.7          5.1         1.6  Iris-versicolor
# ...

# %%
#method2
df[(df["PetalLength"]>4) & (df["SepalWidth"]<3)]
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth          Species
# 54           6.5         2.8          4.6         1.5  Iris-versicolor
# 55           5.7         2.8          4.5         1.3  Iris-versicolor
# 58           6.6         2.9          4.6         1.3  Iris-versicolor
# 63           6.1         2.9          4.7         1.4  Iris-versicolor
# 67           5.8         2.7          4.1         1.0  Iris-versicolor
# 68           6.2         2.2          4.5         1.5  Iris-versicolor
# 72           6.3         2.5          4.9         1.5  Iris-versicolor
# 73           6.1         2.8          4.7         1.2  Iris-versicolor
# 74           6.4         2.9          4.3         1.3  Iris-versicolor
# 76           6.8         2.8          4.8         1.4  Iris-versicolor
# 78           6.0         2.9          4.5         1.5  Iris-versicolor
# 83           6.0         2.7          5.1         1.6  Iris-versicolor
# ...

# %% [markdown]
# ### Q5
# #### a. Calculate the minimum petallength across all species

# %%
df["PetalLength"].min()
# Out:
# 1.0

# %% [markdown]
# #### b. Calculate the maximum SepalWidth across all species

# %%
df[df['SepalWidth'] == df['SepalWidth'].max()]
# Out:
#     SepalLength  SepalWidth  PetalLength  PetalWidth      Species
# 15          5.7         4.4          1.5         0.4  Iris-setosa

# %% [markdown]
# ### Q6
# #### a.Calculate the sm of values along axis =1 (row_wise)

# %%
df.select_dtypes(include = 'number').sum(axis=1)
# Out:
# 0      10.2
# 1       9.5
# 2       9.4
# 3       9.4
# 4      10.2
#        ...
# 145    17.2
# 146    15.7
# 147    16.7
# 148    17.3
# 149    15.8
# Length: 150, dtype: float64

# %% [markdown]
# #### b. Calculate the mean of values along axis = 0

# %%
df.select_dtypes(include = 'number').mean(axis=0)
# Out:
# SepalLength    5.843333
# SepalWidth     3.054000
# PetalLength    3.758667
# PetalWidth     1.198667
# dtype: float64

# %% [markdown]
# ### Q7
# #### Add a new column "petalArea" ca;culated as product of "PetalLength" and "PetalWidth"

# %%
df["PetalArea"] = df['PetalLength']*df['PetalWidth']
df['PetalArea']
# Out:
# 0       0.28
# 1       0.28
# 2       0.26
# 3       0.30
# 4       0.28
#        ...
# 145    11.96
# 146     9.50
# 147    10.40
# 148    12.42
# 149     9.18
# Name: PetalArea, Length: 150, dtype: float64

# %% [markdown]
# ### Q8
# #### Convert the SepalLength column to float dtype using astype

# %%
df['SepalLength']=df['SepalLength'].astype('float')

# %% [markdown]
# ###Q9
# #### Query the DataFrame to show rows where PetalLength is Grater than SepalLength

# %%
#method 1 easy
df.query("PetalLength > SepalLength")
# Out:
# Empty DataFrame
# Columns: [SepalLength, SepalWidth, PetalLength, PetalWidth, Species, PetalArea]
# Index: []

# %%
#method2
df[df['PetalLength'] > df['SepalLength']]
# Out:
# Empty DataFrame
# Columns: [SepalLength, SepalWidth, PetalLength, PetalWidth, Species, PetalArea]
# Index: []

# %% [markdown]
# ### Q 10
# #### Apply a function to calculate the difference between PetalLength and SepalLength for each row

# %%
df["diff"]=df['PetalLength'] - df['SepalLength']
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth         Species  \
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
#      PetalArea  diff
# 0         0.28  -3.7
# 1         0.28  -3.5
# 2         0.26  -3.4
# 3         0.30  -3.1
# ...

# %% [markdown]
# ### Q 11
# #### a. FInd the top 3 rows with the largest "PetalLength"

# %%
df['PetalLength'].sort_values(ascending = False).head(3)
# Out:
# 118    6.9
# 122    6.7
# 117    6.7
# Name: PetalLength, dtype: float64

# %% [markdown]
# #### b Find the top 3 rows with the smallest "sepalWidth"

# %%
df['SepalWidth'].sort_values().head(3)
# Out:
# 60     2.0
# 62     2.2
# 119    2.2
# Name: SepalWidth, dtype: float64

# %% [markdown]
# ### Q 12
# #### a. Sort the DataFrame by "Petalwidth" in ascending order

# %%
df.sort_values(by="PetalWidth")
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth         Species  \
# 32           5.2         4.1          1.5         0.1     Iris-setosa
# 13           4.3         3.0          1.1         0.1     Iris-setosa
# 37           4.9         3.1          1.5         0.1     Iris-setosa
# 9            4.9         3.1          1.5         0.1     Iris-setosa
# 12           4.8         3.0          1.4         0.1     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 140          6.7         3.1          5.6         2.4  Iris-virginica
# 114          5.8         2.8          5.1         2.4  Iris-virginica
# 100          6.3         3.3          6.0         2.5  Iris-virginica
# 144          6.7         3.3          5.7         2.5  Iris-virginica
# 109          7.2         3.6          6.1         2.5  Iris-virginica
#
#      PetalArea  diff
# 32        0.15  -3.7
# 13        0.11  -3.2
# 37        0.15  -3.4
# 9         0.15  -3.4
# ...

# %% [markdown]
# #### b. Sort the DataFrame by 'sepalLength' in descending order

# %%
df.sort_values(by="SepalLength",ascending= False)
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth         Species  \
# 131          7.9         3.8          6.4         2.0  Iris-virginica
# 135          7.7         3.0          6.1         2.3  Iris-virginica
# 122          7.7         2.8          6.7         2.0  Iris-virginica
# 117          7.7         3.8          6.7         2.2  Iris-virginica
# 118          7.7         2.6          6.9         2.3  Iris-virginica
# ..           ...         ...          ...         ...             ...
# 41           4.5         2.3          1.3         0.3     Iris-setosa
# 42           4.4         3.2          1.3         0.2     Iris-setosa
# 38           4.4         3.0          1.3         0.2     Iris-setosa
# 8            4.4         2.9          1.4         0.2     Iris-setosa
# 13           4.3         3.0          1.1         0.1     Iris-setosa
#
#      PetalArea  diff
# 131      12.80  -1.5
# 135      14.03  -1.6
# 122      13.40  -1.0
# 117      14.74  -1.0
# ...
